# %%
import pandas as pd

# %%
#sheets=pd.read_excel('2. Manufacturing.xlsx', sheet_name=['Tata Chemicals','Reliance Power'])
sheet_tatachem=pd.read_excel('2. Manufacturing.xlsx', sheet_name=['Tata Chemicals'])
sheet_relpow=pd.read_excel('2. Manufacturing.xlsx', sheet_name=['Reliance Power'])

# %%
sheet_tatachem
# Out:
# OrderedDict([('Tata Chemicals',
#                  Key Financial Ratios of Tata Chemicals  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
#               0                                     NaN         NaN         NaN         NaN
#               1                                     NaN         NaN         NaN         NaN
#               2                                     NaN     2007.00     2008.00     2009.00
#               3                    Profitability Ratios         NaN         NaN         NaN
#               4                        PBDIT Margin (%)       20.52       32.42       11.33
#               5                         PBIT Margin (%)       16.71       28.73        9.38
#               6                          PBT Margin (%)       15.63       28.21        7.64
#               7                   Net Profit Margin (%)       11.25       23.51        5.40
#               8         Return on Networth / Equity (%)       18.56       26.57       12.48
# ...

# %%
sheets_dict=pd.read_excel('2. Manufacturing.xlsx', sheet_name=None)

# %%
full_table = pd.DataFrame()
for name, sheet in sheets_dict.items():
    sheet['sheet'] = name
    sheet = sheet.rename(columns=lambda x: x.split('\n')[-1])
    full_table = full_table.append(sheet)

full_table.reset_index(inplace=True, drop=True)

full_table.columns
full_table.to_excel(r'fulldata.xlsx')

# %%
for key, value in sheet_tatachem.items() 
    print(key,value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-644e7603b8cd> in <module>
# ----> 1 sheet_tatachem.items().key()
#
# AttributeError: 'odict_items' object has no attribute 'key'

# %%
sheet_tatachem.items().
# Out:
# odict_items([('Tata Chemicals',    Key Financial Ratios of Tata Chemicals  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                     NaN         NaN         NaN         NaN
# 1                                     NaN         NaN         NaN         NaN
# 2                                     NaN     2007.00     2008.00     2009.00
# 3                    Profitability Ratios         NaN         NaN         NaN
# 4                        PBDIT Margin (%)       20.52       32.42       11.33
# 5                         PBIT Margin (%)       16.71       28.73        9.38
# 6                          PBT Margin (%)       15.63       28.21        7.64
# 7                   Net Profit Margin (%)       11.25       23.51        5.40
# 8         Return on Networth / Equity (%)       18.56       26.57       12.48
# 9          Return on Capital Employed (%)       13.08       22.61       10.07
# 10                   Return on Assets (%)        9.28       12.58        4.61
# ...

# %%
sheet_tatachem, sheet_relpow
# Out:
# (OrderedDict([('Tata Chemicals',
#                   Key Financial Ratios of Tata Chemicals  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
#                0                                     NaN         NaN         NaN         NaN
#                1                                     NaN         NaN         NaN         NaN
#                2                                     NaN     2007.00     2008.00     2009.00
#                3                    Profitability Ratios         NaN         NaN         NaN
#                4                        PBDIT Margin (%)       20.52       32.42       11.33
#                5                         PBIT Margin (%)       16.71       28.73        9.38
#                6                          PBT Margin (%)       15.63       28.21        7.64
#                7                   Net Profit Margin (%)       11.25       23.51        5.40
#                8         Return on Networth / Equity (%)       18.56       26.57       12.48
# ...

# %%
df_tatachem=pd.concat( sheet_tatachem[frame] for frame in sheet_tatachem.keys())
df_relpow=pd.concat( sheet_relpow[frame] for frame in sheet_relpow.keys())

# %%
df_tatachem
# Out:
#                                FinRatio  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                   NaN         NaN         NaN         NaN
# 1                                   NaN         NaN         NaN         NaN
# 2                                   NaN     2007.00     2008.00     2009.00
# 3                  Profitability Ratios         NaN         NaN         NaN
# 4                      PBDIT Margin (%)       20.52       32.42       11.33
# 5                       PBIT Margin (%)       16.71       28.73        9.38
# 6                        PBT Margin (%)       15.63       28.21        7.64
# 7                 Net Profit Margin (%)       11.25       23.51        5.40
# 8       Return on Networth / Equity (%)       18.56       26.57       12.48
# 9        Return on Capital Employed (%)       13.08       22.61       10.07
# 10                 Return on Assets (%)        9.28       12.58        4.61
# ...

# %%
df_tatachem[df_tatachem['Key Financial Ratios of Tata Chemicals'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Key Financial Ratios of Tata Chemicals'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-6bfa7646b91d> in <module>
#       1
# ...

# %%
for col in df_tatachem.columns: 
    print(col)
# Out:
# Key Financial Ratios of Tata Chemicals
# Unnamed: 1
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6
# Unnamed: 7
# Unnamed: 8
# Unnamed: 9
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
# Unnamed: 13
# Unnamed: 14
# Unnamed: 15
# Unnamed: 16
# Unnamed: 17
# Unnamed: 18
# Unnamed: 19

# %%
df_tatachem.rename(columns={ df_tatachem.columns[0]: "FinRatio" }, inplace = True)

# %%
df_tatachem[df_tatachem['FinRatio'].isnull()]
# Out:
#    FinRatio  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0       NaN         NaN         NaN         NaN        NaN
# 1       NaN         NaN         NaN         NaN        NaN
# 2       NaN      2007.0      2008.0      2009.0   Pre-Mean
# 14      NaN         NaN         NaN         NaN     20.071
# 17      NaN         NaN         NaN         NaN        NaN
# 18      NaN         NaN         NaN         NaN        NaN
# 22      NaN         NaN         NaN         NaN   0.763333
# 30      NaN         NaN         NaN         NaN    46.8856
# 40      NaN         NaN         NaN         NaN    859.421
#
#              Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0                   NaN         NaN         NaN         NaN        NaN
# 1                   NaN         NaN         NaN         NaN        NaN
# 2   2017-03-10 00:00:00      2011.0      2012.0      2013.0  Post-Mean
# 14                  NaN         NaN         NaN         NaN    14.2873
# ...

# %%
df_tatachem.insert(0, 'Company', )

# %%
df_tatachem
# Out:
#                                FinRatio  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                   NaN         NaN         NaN         NaN
# 1                                   NaN         NaN         NaN         NaN
# 2                                   NaN     2007.00     2008.00     2009.00
# 3                  Profitability Ratios         NaN         NaN         NaN
# 4                      PBDIT Margin (%)       20.52       32.42       11.33
# 5                       PBIT Margin (%)       16.71       28.73        9.38
# 6                        PBT Margin (%)       15.63       28.21        7.64
# 7                 Net Profit Margin (%)       11.25       23.51        5.40
# 8       Return on Networth / Equity (%)       18.56       26.57       12.48
# 9        Return on Capital Employed (%)       13.08       22.61       10.07
# 10                 Return on Assets (%)        9.28       12.58        4.61
# ...

# %%
df_tatachem <- df_tatachem[colSums(is.na(df_tatachem))<nrow(df_tatachem)]
# Out:
#   File "<ipython-input-98-5b10b6f2ef3e>", line 1
#     df_tatachem <- df_tatachem[colSums(is.na(df_tatachem))<nrow(df_tatachem)]
#                                         ^
# SyntaxError: invalid syntax

# %%
df_tatachem.isna().sum()=len(df_tatachem)
# Out:
# FinRatio        9
# Unnamed: 1     13
# Unnamed: 2     13
# Unnamed: 3     13
# Unnamed: 4      9
# Unnamed: 5     13
# Unnamed: 6     13
# Unnamed: 7     13
# Unnamed: 8     13
# Unnamed: 9      9
# Unnamed: 10    41
# Unnamed: 11    41
# Unnamed: 12    41
# Unnamed: 13    41
# Unnamed: 14    41
# Unnamed: 15    41
# Unnamed: 16    41
# Unnamed: 17    41
# Unnamed: 18    41
# Unnamed: 19    41
# dtype: int64

# %%
df_tatachem1 = df_tatachem.loc[:, (df_tatachem.isnull().sum(axis=0) < len(df_tatachem))]

# %%
df_tatachem1
# Out:
#                                FinRatio  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                   NaN         NaN         NaN         NaN
# 1                                   NaN         NaN         NaN         NaN
# 2                                   NaN     2007.00     2008.00     2009.00
# 3                  Profitability Ratios         NaN         NaN         NaN
# 4                      PBDIT Margin (%)       20.52       32.42       11.33
# 5                       PBIT Margin (%)       16.71       28.73        9.38
# 6                        PBT Margin (%)       15.63       28.21        7.64
# 7                 Net Profit Margin (%)       11.25       23.51        5.40
# 8       Return on Networth / Equity (%)       18.56       26.57       12.48
# 9        Return on Capital Employed (%)       13.08       22.61       10.07
# 10                 Return on Assets (%)        9.28       12.58        4.61
# ...
